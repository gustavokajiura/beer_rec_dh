# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
driver = webdriver.Chrome(executable_path='./chromedriver.exe')
import pandas as pd
import time
from requests import get
from random import randrange

# %%
#url que iremos analisar
url = 'https://www.brejas.com.br/cerveja/mais-avaliadas'
response = get(url)
# chamada da página, deve abrir também a página on browser controlado pelo Selenium
driver.get('https://www.brejas.com.br/cerveja/mais-avaliadas')

# %% [markdown]
# # Iterando

# %%
df=pd.DataFrame()
df.head()

df_2=pd.DataFrame()
df_2.head()

# %%
iii=1
#Iterando nas paginas
for paginas in range(20):
    driver.get('https://www.brejas.com.br/cerveja/mais-avaliadas?page='+str(iii))
    time.sleep(randrange(5,8))
    

    jjj=0
    
    #iterando nas cervejas de cada pagina
    for jjj in range(10):
        produtosnome = driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrTableGrid.jrDataList.jrResults > div:nth-child('+str(jjj+2)+') > div.jr-listing-outer.jrCol.jrTableColumnMain > div.jrListingTitle > a')
        element = produtosnome
        element.click()
        time.sleep(randrange(5,8))

        i=1
        
        try:
            produtosnomedet = driver.find_elements_by_class_name('contentheading')
        except:
            pass

        try:
            produtossazonal=driver.find_element_by_css_selector('body > div.uk-container.uk-container-center > div.tm-middle.uk-grid > div > main > div.item-page > div > div > div.jrCustomFields > div > div.jrFieldRow.jrSazonal > div.jrFieldValue > a')
            produtossazonal=produtossazonal.text
        except:
            produtossazonal=""

        try:
            produtostemperatura=driver.find_element_by_css_selector('body > div.uk-container.uk-container-center > div.tm-middle.uk-grid > div > main > div.item-page > div > div > div.jrCustomFields > div > div.jrFieldRow.jrTemperatura > div.jrFieldValue > a:nth-child(1)')
            produtostemperatura=produtostemperatura.text
        except:
            produtostemperatura=""


        try:
            produtosdescricao = driver.find_elements_by_class_name('jrListingFulltext')
            produtosdescricao = produtosdescricao[0].text
        except:
            produtosdescricao = ""


        try:
            produtoscervejaria=driver.find_element_by_css_selector('body > div.uk-container.uk-container-center > div.tm-middle.uk-grid > div > main > div.item-page > div > div > div.jrCustomFields > div > div.jrFieldRow.jrCervejaria > div.jrFieldValue > a > span')
            produtoscervejaria=produtoscervejaria.text
        except:
            produtoscervejaria=""

        try:
            produtosestilo=driver.find_element_by_css_selector('body > div.uk-container.uk-container-center > div.tm-middle.uk-grid > div > main > div.item-page > div > div > div.jrCustomFields > div > div.jrFieldRow.jrEstilo > div.jrFieldValue > a:nth-child(1)')
            produtosestilo=produtosestilo.text
        except:
            produtosestilo=""

        try:
            produtosabv=driver.find_element_by_css_selector('body > div.uk-container.uk-container-center > div.tm-middle.uk-grid > div > main > div.item-page > div > div > div.jrCustomFields > div > div.jrFieldRow.jrAlcool > div.jrFieldValue')
            produtosabv=produtosabv.text
        except:
            produtosabv=""


        try:
            copoideal=driver.find_element_by_css_selector('body > div.uk-container.uk-container-center > div.tm-middle.uk-grid > div > main > div.item-page > div > div > div.jrCustomFields > div > div.jrFieldRow.jrCopo > div.jrFieldValue > a:nth-child(2)')
            copoideal=copoideal.text
        except:
            copoideal=""

        try:
            produtosibu=driver.find_element_by_css_selector('body > div.uk-container.uk-container-center > div.tm-middle.uk-grid > div > main > div.item-page > div > div > div.jrCustomFields > div > div.jrFieldRow.jrIbu > div.jrFieldValue')
            produtosibu=produtosibu.text
        except:
            produtosibu=""

        try:
            avaliacaogeral=driver.find_element_by_css_selector('#userReviews > div.jrRoundedPanel.jrReview.jrUserReviewsSummary > div > div.jrGrid > div:nth-child(2) > div > div.jrTableGrid.jrRatingTable > div:nth-child(1) > div.jrCol.jrRatingValue')
            aroma=driver.find_element_by_css_selector('#userReviews > div.jrRoundedPanel.jrReview.jrUserReviewsSummary > div > div.jrGrid > div:nth-child(2) > div > div.jrTableGrid.jrRatingTable > div:nth-child(2) > div.jrCol.jrRatingValue')
            aparencia=driver.find_element_by_css_selector('#userReviews > div.jrRoundedPanel.jrReview.jrUserReviewsSummary > div > div.jrGrid > div:nth-child(2) > div > div.jrTableGrid.jrRatingTable > div:nth-child(3) > div.jrCol.jrRatingValue')
            sabor=driver.find_element_by_css_selector('#userReviews > div.jrRoundedPanel.jrReview.jrUserReviewsSummary > div > div.jrGrid > div:nth-child(2) > div > div.jrTableGrid.jrRatingTable > div:nth-child(4) > div.jrCol.jrRatingValue')
            sensacao=driver.find_element_by_css_selector('#userReviews > div.jrRoundedPanel.jrReview.jrUserReviewsSummary > div > div.jrGrid > div:nth-child(2) > div > div.jrTableGrid.jrRatingTable > div:nth-child(5) > div.jrCol.jrRatingValue')
            conjunto=driver.find_element_by_css_selector('#userReviews > div.jrRoundedPanel.jrReview.jrUserReviewsSummary > div > div.jrGrid > div:nth-child(2) > div > div.jrTableGrid.jrRatingTable > div:nth-child(6) > div.jrCol.jrRatingValue')
        except:
            pass
        
        try:
            df_2 = df_2.append({'Nome_Cerva': produtosnomedet[0].text,'Sazonalidade': produtossazonal,'Temperatura':produtostemperatura,'IBU':produtosibu,'Copo_Ideal':copoideal,'Descricao':produtosdescricao,'Cervejaria':produtoscervejaria,'Estilo':produtosestilo,'ABV':produtosabv,'Rating_Geral': avaliacaogeral.text,'Aroma': aroma.text,'Aparencia': aparencia.text,'Sabor': sabor.text,'Sensacao': sensacao.text,'Conjunto': conjunto.text}, ignore_index=True)
        except:
            pass        
        
        comentario = driver.find_element_by_css_selector('#userReviews > a')
        comentarioclicando = comentario
        comentarioclicando.click()
        time.sleep(randrange(5,8))
        
        
        kkkk=0
        
        
        for kkkk in range(10):

            
            for i in range(1,6):

                try:
                    produtosnomedf = driver.find_elements_by_class_name('contentheading')
                except:
                    pass

                try:
                    nome=driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrReviewListDetail > div:nth-child('+str(i)+') > div > div.jrReviewLayoutLeft.jrUserInfo > div > span:nth-child(1) > a > span')        
                    nome=nome.text
                except:
                    nome=""


                try:
                    comentarios=driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrReviewListDetail > div:nth-child('+str(i)+') > div > div.jrReviewLayoutRight.jrReviewContent > div.description.jrReviewComment > div')
                    comentarios=comentarios.text
                except:
                    comentarios=""


                try:    
                    rating=driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrReviewListDetail > div:nth-child('+str(i)+') > div > div.jrReviewLayoutRight.jrReviewContent > div.jrRatingInfo > div.jrTableGrid.jrRatingTable > div:nth-child(1) > div.jrCol.jrRatingValue')
                    rating=rating.text
                except:
                    rating=""      

                try:    
                    aroma=driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrReviewListDetail > div:nth-child('+str(i)+') > div > div.jrReviewLayoutRight.jrReviewContent > div.jrRatingInfo > div.jrTableGrid.jrRatingTable > div:nth-child(2) > div.jrCol.jrRatingValue')
                    aroma=aroma.text
                except:
                    aroma=""    

                try:
                    aparencia=driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrReviewListDetail > div:nth-child('+str(i)+') > div > div.jrReviewLayoutRight.jrReviewContent > div.jrRatingInfo > div.jrTableGrid.jrRatingTable > div:nth-child(3) > div.jrCol.jrRatingValue')
                    aparencia=aparencia.text
                except:
                    aparencia=""    


                try:
                    sabor=driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrReviewListDetail > div:nth-child('+str(i)+') > div > div.jrReviewLayoutRight.jrReviewContent > div.jrRatingInfo > div.jrTableGrid.jrRatingTable > div:nth-child(4) > div.jrCol.jrRatingValue')
                    sabor=sabor.text
                except:
                    sabor=""


                try:
                    sensacao=driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrReviewListDetail > div:nth-child('+str(i)+') > div > div.jrReviewLayoutRight.jrReviewContent > div.jrRatingInfo > div.jrTableGrid.jrRatingTable > div:nth-child(5) > div.jrCol.jrRatingValue')
                    sensacao=sensacao.text
                except:
                    sensacao=""



                try:
                    conjunto=driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrReviewListDetail > div:nth-child('+str(i)+') > div > div.jrReviewLayoutRight.jrReviewContent > div.jrRatingInfo > div.jrTableGrid.jrRatingTable > div:nth-child(6) > div.jrCol.jrRatingValue')
                    conjunto=conjunto.text
                except:
                    conjunto=""


                try:    
                    data=driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrReviewListDetail > div:nth-child('+str(i)+') > div > div.jrReviewLayoutRight.jrReviewContent > div.jrReviewHeader > div > time')
                    data=data.text
                except:
                    data=""

                try:
                    df = df.append({'Nome': nome,'Comentario': comentarios,'Rating_Geral': rating,'Aroma': aroma,'Aparencia': aparencia,'Sabor': sabor,'Sensacao': sensacao,'Conjunto': conjunto,'Data': data,'Nome_Cerveja':produtosnomedf[0].text}, ignore_index=True)
                except:
                    pass

            try:
                #proximapagina = driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jr-pagenav.jrTableGrid.jrPagination.jrPaginationTop > div.jrCol4.jrPagenavPages > a:nth-child('+str(kkkk+3)+')')
                proximapagina = driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jr-pagenav.jrTableGrid.jrPagination.jrPaginationTop > div.jrCol4.jrPagenavPages > a.jr-pagenav-next.jrButton.jrSmall')
                proximapaginaclick = proximapagina
                proximapaginaclick.click()
                time.sleep(randrange(5,8))
            except:
                pass
                
        driver.get('https://www.brejas.com.br/cerveja/mais-avaliadas?page='+str(iii))
        time.sleep(randrange(5,8))
        
    iii=iii+1
    time.sleep(randrange(5,8))

# %%
len(df.Nome_Cerveja.unique())
# Out:
# 170

# %%
len(df_2.Nome_Cerva.unique())
# Out:
# 170

# %%
df
# Out:
#      Aparencia Aroma                                         Comentario  \
# 0          4/5  8/10     Muito saborosa. Acho um ótimo custo beneficio.
# 1          3/5  5/10  O líquido formou uma mediana camada de creme b...
# 2          3/5  7/10  Das cervejas das grandes indústrias, para mim ...
# 3          3/5  7/10
# 4          4/5  6/10
# ...        ...   ...                                                ...
# 8773       4/5  9/10  Aroma muito parecido com groselha. Perfeito! O...
# 8774       4/5  8/10  Marrom. Boa espuma, de média duração e levemen...
# 8775       4/5  8/10  Cor marrom opaca deixando transparecer apenas ...
# 8776       4/5  8/10  Aromas e sabor de mel e malte torrado. Muito boa!
# 8777       4/5  8/10  Ótima cerveja belga!\nDestaque para o chocolat...
#
#      Conjunto                   Data                       Nome  \
# 0        8/10   19 de Agosto de 2020    Pedro Augusto Alcantara
# 1        7/10    06 de Junho de 2020            Rafael Beltrame
# ...

# %%
df_2
# Out:
#            ABV   Aparencia        Aroma             Cervejaria     Conjunto  \
# 0       5% ABV  3/5  (817)  6/10  (817)    Cervejaria Heineken  7/10  (817)
# 1     4.9% ABV  4/5  (609)  7/10  (609)   Brouwerij Hoegaarden  8/10  (609)
# 2     4.8% ABV  3/5  (426)  5/10  (426)    Cervejaria Sudbrack  6/10  (426)
# 3       5% ABV  3/5  (357)  4/10  (357)                  AmBev  5/10  (357)
# 4     5.5% ABV  3/5  (306)  4/10  (306)                  AmBev  5/10  (306)
# ..         ...         ...          ...                    ...          ...
# 171  10.5% ABV  4/5  (150)  8/10  (150)  St. Bernard Brouwerij  9/10  (150)
# 172    10% ABV  4/5  (148)  8/10  (148)       Brooklyn Brewery  8/10  (148)
# 173   4.8% ABV  2/5  (145)  3/10  (145)     Cervejaria Devassa  4/10  (145)
# 174   5.4% ABV  3/5  (145)  4/10  (145)                   Damm  5/10  (145)
# 175   8.5% ABV  4/5  (143)  8/10  (143)    Brouwerij Het Anker  8/10  (143)
#
# ...

# %%
df.to_csv('comentarios_utf16.csv', encoding='utf-16')
df_2.to_csv('cervejas_utf16.csv', encoding='utf-16')
df.to_csv('comentarios.csv')
df_2.to_csv('cervejas.csv')
df.to_csv('comentarios_utf8.csv', encoding='utf-8')
df_2.to_csv('cervejas_utf8.csv', encoding='utf-8')

# %%
df
# Out:
#       Aparencia Aroma                                         Comentario  \
# 0           4/5  8/10     Muito saborosa. Acho um ótimo custo beneficio.
# 1           3/5  5/10  O líquido formou uma mediana camada de creme b...
# 2           3/5  7/10  Das cervejas das grandes indústrias, para mim ...
# 3           3/5  7/10
# 4           4/5  6/10
# ...         ...   ...                                                ...
# 10723       3/5  8/10                                                  .
# 10724       3/5  6/10  Boa cerveja.\nÂmbar, creme claro.\nAroma de ma...
# 10725       3/5  7/10  Cor âmbar claro, espuma de boa persistência, a...
# 10726       4/5  7/10  Coloração acobreada, muito boa formação de esp...
# 10727       5/5  8/10  Cerveja de coloração dourada acobreada, com ap...
#
#       Conjunto                    Data                     Nome  \
# 0         8/10    19 de Agosto de 2020  Pedro Augusto Alcantara
# ...

# %%
iii=49
#Iterando nas paginas
for paginas in range(13):
    driver.get('https://www.brejas.com.br/cerveja/mais-avaliadas?page='+str(iii))
    time.sleep(randrange(5,8))
    

    jjj=0
    
    #iterando nas cervejas de cada pagina
    for jjj in range(10):
        produtosnome = driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrTableGrid.jrDataList.jrResults > div:nth-child('+str(jjj+2)+') > div.jr-listing-outer.jrCol.jrTableColumnMain > div.jrListingTitle > a')
        element = produtosnome
        element.click()
        time.sleep(randrange(5,8))

        i=1
        
        try:
            produtosnomedet = driver.find_elements_by_class_name('contentheading')
        except:
            pass

        try:
            produtossazonal=driver.find_element_by_css_selector('body > div.uk-container.uk-container-center > div.tm-middle.uk-grid > div > main > div.item-page > div > div > div.jrCustomFields > div > div.jrFieldRow.jrSazonal > div.jrFieldValue > a')
            produtossazonal=produtossazonal.text
        except:
            produtossazonal=""

        try:
            produtostemperatura=driver.find_element_by_css_selector('body > div.uk-container.uk-container-center > div.tm-middle.uk-grid > div > main > div.item-page > div > div > div.jrCustomFields > div > div.jrFieldRow.jrTemperatura > div.jrFieldValue > a:nth-child(1)')
            produtostemperatura=produtostemperatura.text
        except:
            produtostemperatura=""


        try:
            produtosdescricao = driver.find_elements_by_class_name('jrListingFulltext')
            produtosdescricao = produtosdescricao[0].text
        except:
            produtosdescricao = ""


        try:
            produtoscervejaria=driver.find_element_by_css_selector('body > div.uk-container.uk-container-center > div.tm-middle.uk-grid > div > main > div.item-page > div > div > div.jrCustomFields > div > div.jrFieldRow.jrCervejaria > div.jrFieldValue > a > span')
            produtoscervejaria=produtoscervejaria.text
        except:
            produtoscervejaria=""

        try:
            produtosestilo=driver.find_element_by_css_selector('body > div.uk-container.uk-container-center > div.tm-middle.uk-grid > div > main > div.item-page > div > div > div.jrCustomFields > div > div.jrFieldRow.jrEstilo > div.jrFieldValue > a:nth-child(1)')
            produtosestilo=produtosestilo.text
        except:
            produtosestilo=""

        try:
            produtosabv=driver.find_element_by_css_selector('body > div.uk-container.uk-container-center > div.tm-middle.uk-grid > div > main > div.item-page > div > div > div.jrCustomFields > div > div.jrFieldRow.jrAlcool > div.jrFieldValue')
            produtosabv=produtosabv.text
        except:
            produtosabv=""


        try:
            copoideal=driver.find_element_by_css_selector('body > div.uk-container.uk-container-center > div.tm-middle.uk-grid > div > main > div.item-page > div > div > div.jrCustomFields > div > div.jrFieldRow.jrCopo > div.jrFieldValue > a:nth-child(2)')
            copoideal=copoideal.text
        except:
            copoideal=""

        try:
            produtosibu=driver.find_element_by_css_selector('body > div.uk-container.uk-container-center > div.tm-middle.uk-grid > div > main > div.item-page > div > div > div.jrCustomFields > div > div.jrFieldRow.jrIbu > div.jrFieldValue')
            produtosibu=produtosibu.text
        except:
            produtosibu=""

        try:
            avaliacaogeral=driver.find_element_by_css_selector('#userReviews > div.jrRoundedPanel.jrReview.jrUserReviewsSummary > div > div.jrGrid > div:nth-child(2) > div > div.jrTableGrid.jrRatingTable > div:nth-child(1) > div.jrCol.jrRatingValue')
            aroma=driver.find_element_by_css_selector('#userReviews > div.jrRoundedPanel.jrReview.jrUserReviewsSummary > div > div.jrGrid > div:nth-child(2) > div > div.jrTableGrid.jrRatingTable > div:nth-child(2) > div.jrCol.jrRatingValue')
            aparencia=driver.find_element_by_css_selector('#userReviews > div.jrRoundedPanel.jrReview.jrUserReviewsSummary > div > div.jrGrid > div:nth-child(2) > div > div.jrTableGrid.jrRatingTable > div:nth-child(3) > div.jrCol.jrRatingValue')
            sabor=driver.find_element_by_css_selector('#userReviews > div.jrRoundedPanel.jrReview.jrUserReviewsSummary > div > div.jrGrid > div:nth-child(2) > div > div.jrTableGrid.jrRatingTable > div:nth-child(4) > div.jrCol.jrRatingValue')
            sensacao=driver.find_element_by_css_selector('#userReviews > div.jrRoundedPanel.jrReview.jrUserReviewsSummary > div > div.jrGrid > div:nth-child(2) > div > div.jrTableGrid.jrRatingTable > div:nth-child(5) > div.jrCol.jrRatingValue')
            conjunto=driver.find_element_by_css_selector('#userReviews > div.jrRoundedPanel.jrReview.jrUserReviewsSummary > div > div.jrGrid > div:nth-child(2) > div > div.jrTableGrid.jrRatingTable > div:nth-child(6) > div.jrCol.jrRatingValue')
        except:
            pass
        
        try:
            df_2 = df_2.append({'Nome_Cerva': produtosnomedet[0].text,'Sazonalidade': produtossazonal,'Temperatura':produtostemperatura,'IBU':produtosibu,'Copo_Ideal':copoideal,'Descricao':produtosdescricao,'Cervejaria':produtoscervejaria,'Estilo':produtosestilo,'ABV':produtosabv,'Rating_Geral': avaliacaogeral.text,'Aroma': aroma.text,'Aparencia': aparencia.text,'Sabor': sabor.text,'Sensacao': sensacao.text,'Conjunto': conjunto.text}, ignore_index=True)
        except:
            pass        
        
        comentario = driver.find_element_by_css_selector('#userReviews > a')
        comentarioclicando = comentario
        comentarioclicando.click()
        time.sleep(randrange(5,8))
        
        
        kkkk=0
        
        
        for kkkk in range(10):

            
            for i in range(1,6):

                try:
                    produtosnomedf = driver.find_elements_by_class_name('contentheading')
                except:
                    pass

                try:
                    nome=driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrReviewListDetail > div:nth-child('+str(i)+') > div > div.jrReviewLayoutLeft.jrUserInfo > div > span:nth-child(1) > a > span')        
                    nome=nome.text
                except:
                    nome=""


                try:
                    comentarios=driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrReviewListDetail > div:nth-child('+str(i)+') > div > div.jrReviewLayoutRight.jrReviewContent > div.description.jrReviewComment > div')
                    comentarios=comentarios.text
                except:
                    comentarios=""


                try:    
                    rating=driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrReviewListDetail > div:nth-child('+str(i)+') > div > div.jrReviewLayoutRight.jrReviewContent > div.jrRatingInfo > div.jrTableGrid.jrRatingTable > div:nth-child(1) > div.jrCol.jrRatingValue')
                    rating=rating.text
                except:
                    rating=""      

                try:    
                    aroma=driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrReviewListDetail > div:nth-child('+str(i)+') > div > div.jrReviewLayoutRight.jrReviewContent > div.jrRatingInfo > div.jrTableGrid.jrRatingTable > div:nth-child(2) > div.jrCol.jrRatingValue')
                    aroma=aroma.text
                except:
                    aroma=""    

                try:
                    aparencia=driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrReviewListDetail > div:nth-child('+str(i)+') > div > div.jrReviewLayoutRight.jrReviewContent > div.jrRatingInfo > div.jrTableGrid.jrRatingTable > div:nth-child(3) > div.jrCol.jrRatingValue')
                    aparencia=aparencia.text
                except:
                    aparencia=""    


                try:
                    sabor=driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrReviewListDetail > div:nth-child('+str(i)+') > div > div.jrReviewLayoutRight.jrReviewContent > div.jrRatingInfo > div.jrTableGrid.jrRatingTable > div:nth-child(4) > div.jrCol.jrRatingValue')
                    sabor=sabor.text
                except:
                    sabor=""


                try:
                    sensacao=driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrReviewListDetail > div:nth-child('+str(i)+') > div > div.jrReviewLayoutRight.jrReviewContent > div.jrRatingInfo > div.jrTableGrid.jrRatingTable > div:nth-child(5) > div.jrCol.jrRatingValue')
                    sensacao=sensacao.text
                except:
                    sensacao=""



                try:
                    conjunto=driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrReviewListDetail > div:nth-child('+str(i)+') > div > div.jrReviewLayoutRight.jrReviewContent > div.jrRatingInfo > div.jrTableGrid.jrRatingTable > div:nth-child(6) > div.jrCol.jrRatingValue')
                    conjunto=conjunto.text
                except:
                    conjunto=""


                try:    
                    data=driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jrReviewListDetail > div:nth-child('+str(i)+') > div > div.jrReviewLayoutRight.jrReviewContent > div.jrReviewHeader > div > time')
                    data=data.text
                except:
                    data=""

                try:
                    df = df.append({'Nome': nome,'Comentario': comentarios,'Rating_Geral': rating,'Aroma': aroma,'Aparencia': aparencia,'Sabor': sabor,'Sensacao': sensacao,'Conjunto': conjunto,'Data': data,'Nome_Cerveja':produtosnomedf[0].text}, ignore_index=True)
                except:
                    pass

            try:
                #proximapagina = driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jr-pagenav.jrTableGrid.jrPagination.jrPaginationTop > div.jrCol4.jrPagenavPages > a:nth-child('+str(kkkk+3)+')')
                proximapagina = driver.find_element_by_css_selector('#jr-pagenav-ajax > div.jr-pagenav.jrTableGrid.jrPagination.jrPaginationTop > div.jrCol4.jrPagenavPages > a.jr-pagenav-next.jrButton.jrSmall')
                proximapaginaclick = proximapagina
                proximapaginaclick.click()
                time.sleep(randrange(5,8))
            except:
                pass
                
        driver.get('https://www.brejas.com.br/cerveja/mais-avaliadas?page='+str(iii))
        time.sleep(randrange(5,8))
        
    iii=iii+1
    time.sleep(randrange(5,8))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-155-7dbdc192133a> in <module>
#     183
#     184         driver.get('https://www.brejas.com.br/cerveja/mais-avaliadas?page='+str(iii))
# --> 185         time.sleep(randrange(5,8))
#     186
#     187     iii=iii+1
#
# KeyboardInterrupt:

# %%
df.to_csv('comentarios_v2_utf16.csv', encoding='utf-16')
df_2.to_csv('cervejas_v2_utf16.csv', encoding='utf-16')
df.to_csv('comentarios_v2.csv')
df_2.to_csv('cervejas_v2.csv')
df.to_csv('comentarios_v2_utf8.csv', encoding='utf-8')
df_2.to_csv('cervejas_v2_utf8.csv', encoding='utf-8')

# %%
df
# Out:
#       Aparencia Aroma                                         Comentario  \
# 0           4/5  8/10     Muito saborosa. Acho um ótimo custo beneficio.
# 1           3/5  5/10  O líquido formou uma mediana camada de creme b...
# 2           3/5  7/10  Das cervejas das grandes indústrias, para mim ...
# 3           3/5  7/10
# 4           4/5  6/10
# ...         ...   ...                                                ...
# 26720       4/5  4/10  Boa aparência com destaque para o líquido dour...
# 26721       4/5  5/10  Forma uma bela aparência, com uma espuma grand...
# 26722       2/5  4/10  Líquido dourado, com formação de creme branco ...
# 26723       3/5  3/10  Melhor que qualquer água de batata do mercado,...
# 26724       3/5  4/10  Apresentação como das outras cervejas do gêner...
#
#       Conjunto                     Data                                  Nome  \
# 0         8/10     19 de Agosto de 2020               Pedro Augusto Alcantara
# ...

# %%
df_2
# Out:
#           ABV   Aparencia        Aroma               Cervejaria     Conjunto  \
# 0      5% ABV  3/5  (817)  6/10  (817)      Cervejaria Heineken  7/10  (817)
# 1    4.9% ABV  4/5  (609)  7/10  (609)     Brouwerij Hoegaarden  8/10  (609)
# 2    4.8% ABV  3/5  (426)  5/10  (426)      Cervejaria Sudbrack  6/10  (426)
# 3      5% ABV  3/5  (357)  4/10  (357)                    AmBev  5/10  (357)
# 4    5.5% ABV  3/5  (306)  4/10  (306)                    AmBev  5/10  (306)
# ..        ...         ...          ...                      ...          ...
# 529  4.5% ABV   3/5  (59)   5/10  (59)                Krug Bier   5/10  (59)
# 530  5.2% ABV   4/5  (58)   6/10  (58)            Faxe Bryggeri   7/10  (58)
# 531  6.9% ABV   4/5  (58)   7/10  (58)           Cervejaria Way   7/10  (58)
# 532    5% ABV   4/5  (58)   6/10  (58)    Saint Bier Cervejaria   6/10  (58)
# 533    5% ABV   3/5  (58)   5/10  (58)  Cervejaria Riograndense   5/10  (58)
#
# ...

# %%
df.to_csv('comentarios_v2_utf16.csv', encoding='utf-16')
df_2.to_csv('cervejas_v2_utf16.csv', encoding='utf-16')
df.to_csv('comentarios_v2.csv')
df_2.to_csv('cervejas_v2.csv')
df.to_csv('comentarios_v2_utf8.csv', encoding='utf-8')
df_2.to_csv('cervejas_v2_utf8.csv', encoding='utf-8')
